# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
eval_file = "../eval/distance_based_reward_positive_2024-08-13-17-38/evaluation_results.npz"

data = np.load(eval_file, allow_pickle=True)

print(data)
# Out:
# NpzFile '../eval/distance_based_reward_positive_2024-08-13-17-38/evaluation_results.npz' with keys: center, velocity, objective

# %%
print(data["center"])
# Out:
# {0: [0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.05, -0.39, -0.4, 0.05, 0.05, 0.05, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.03, 0.03, 0.02, 0.02, 0.01, 0.0, -0.01, -0.01, -0.02, -0.03, -0.05, -0.06, -0.07, -0.08, -0.1, -0.11, -0.13, -0.15, -0.16, -0.19, -0.21, -0.23, -0.25, -0.27, -0.29, -0.32, -0.35, -0.38, -0.41, -0.45, -0.48, -0.52, -0.56, -0.59, -0.59, -0.63, -0.67, -0.67, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.05, -0.39, -0.4, 0.05, 0.05, 0.05, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.03, 0.03, 0.02, 0.01, 0.01, 0.0, -0.01, -0.01, -0.02, -0.04, -0.05, -0.06, -0.07, -0.08, -0.1, -0.11, -0.13, -0.15, -0.17, -0.19, -0.21, -0.23, -0.25, -0.28, -0.29, -0.32, -0.35, -0.38, -0.42, -0.45, -0.48, -0.52, -0.56, -0.6, -0.63, -0.67, -0.67, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.06, 0.05, -0.39, -0.4, 0.05, 0.05, 0.05, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.03, 0.03, 0.02, 0.02, 0.01, 0.0, -0.01, -0.01, -0.02, -0.03, -0.05, -0.06, -0.07, -0.08, -0.1, -0.11, 
# ...
